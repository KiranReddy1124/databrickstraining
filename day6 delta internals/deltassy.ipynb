# %%
delta internals

# %%
# %sql
use catalog lakehouse;

# %%
# %sql
create schema lakehouse.kiran managed location 'abfss://raw@adlsnaval123.dfs.core.windows.net/lakehouse/kiran'

# %%
# %sql
create table lakehouse.kiran.demo (id int, name string)

# %% [markdown]
# delta internals

# %% [markdown]
# delta
#
# parquet  (data)
# +
# _delta_logs ( metadata)
#
# 1. crc. ==== desc detail table
# 2. json  ==== desc history
# 3. checkpoint parquet ( 10-12 transcation)

# %%
# %sql desc extended lakehouse.kiran.demo

# %%
# %sql
desc detail lakehouse.kiran.demo

# %%
# %sql
desc history lakehouse.kiran.demo

# %%
# %sql
insert into lakehouse.kiran.demo values(1,'Naval')

# %%
# %sql
insert into lakehouse.kiran.demo values(2,'krishna'),(3,'Ram');

# %%
# %sql
delete from lakehouse.kiran.demo where id=1

# %%
# %sql
select * from lakehouse.kiran.demo

# %%
# %sql
Insert into lakehouse.kiran.demo values (4,'Dayanada');
Insert into lakehouse.kiran.demo values (5,'Eswar');
Insert into lakehouse.kiran.demo values (6,'Sangram');

# %%
# %sql
delete from lakehouse.kiran.demo where id=2

# %%
# %sql
update lakehouse.kiran.demo set name='Krishna' where id=3

# %% [markdown]
# Optimize
# small files into large
#
# Zorder
# indexing by id col
#
# Liquid Cluster

# %%
# %sql
optimize lakehouse.kiran.demo
zorder by id

# %% [markdown]
# Vacuum
# no time travel
# delete all unused
# default rentention as 7 days or 168 hours

# %%
# %sql
vacuum lakehouse.kiran.demo

# %%
# %sql
vacuum lakehouse.kiran.demo retain 0 hours

# %%
# %sql
ALTER TABLE lakehouse.kiran.demo
SET TBLPROPERTIES (
  delta.deletedFileRetentionDuration = '0 hours'
)

# %%
# %sql
vacuum lakehouse.kiran.demo retain 0 hours

# %%
# %sql
select * from lakehouse.kiran.demo
